# %% [markdown]
# ## Importando Arquivo

# %%
import pandas as pd

path = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'
data_base = pd.read_csv(path)

# %% [markdown]
# ## Aprendendo e Testando

# %%
data_base.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
data_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
data_base['Valor'][0].split()
# Out:
# ['R$', '7.000.000']

# %%
data_base['Valor'].sample(21)
# Out:
# 5901                             R$ 6.000.000
# 5480                               R$ 950.000
# 2053    R$ 15.000\n                      /Mês
# 610                              R$ 4.500.000
# 8796                             R$ 1.180.000
# 5101                             R$ 2.000.000
# 5504                             R$ 1.300.000
# 706                              R$ 7.700.000
# 3811                             R$ 1.400.000
# 3467    R$ 23.000\n                      /Mês
# 6862                             R$ 3.500.000
# 4772                             R$ 2.970.000
# 9717                             R$ 4.200.000
# 5627                             R$ 1.300.000
# 8891                               R$ 720.000
# 8650                             R$ 4.650.000
# 3554                            R$ 17.000.000
# 1436                             R$ 3.999.000
# 333                                R$ 795.000
# 3104                             R$ 3.600.000
# ...

# %%
for i, j in enumerate(data_base['Valor'].sample(21)):
  print(data_base['Valor'][i].split())
  print(j)
  print()
# Out:
# ['R$', '7.000.000']
# R$ 2.120.000
#
# ['R$', '3.700.000']
# R$ 965.000
#
# ['R$', '380.000']
# R$ 939.000
#
# ['R$', '685.000']
# R$ 2.356.800
#
# ['R$', '540.000']
# R$ 7.400.000
#
# ['R$', '1.980.000']
# R$ 3.500.000
#
# ['R$', '850.000']
# R$ 579.000
#
# ['R$', '450.000']
# R$ 600.000
#
# ['R$', '199.900']
# R$ 3.350.000
#
# ['R$', '585.000']
# R$ 530.000
#
# ['R$', '700.000']
# R$ 800.000
#
# ['R$', '15.000']
# R$ 2.550.000
#
# ['R$', '2.500.000']
# R$ 750.000
#
# ['R$', '1.700.000']
# R$ 8.000.000
#
# ['R$', '1.150.000']
# R$ 1.500.000
#
# ['R$', '550.000']
# R$ 4.400.000
#
# ['R$', '420.000']
# R$ 245.000
#
# ['R$', '2.232.000']
# R$ 1.600.000
#
# ['R$', '2.700.000']
# R$ 360.000
#
# ['R$', '4.190.000']
# R$ 1.100.000
#
# ['R$', '860.000']
# R$ 2.100.000

# %%
for i in data_base['Valor'].sample(21):
  print(i.split())
# Out:
# ['R$', '5.950.000']
# ['R$', '3.200.000']
# ['R$', '750.000']
# ['R$', '2.500.000']
# ['R$', '5.300.000']
# ['R$', '600.000']
# ['R$', '450.000']
# ['R$', '2.500.000']
# ['R$', '1.680.000']
# ['R$', '14.000.000']
# ['R$', '12.000.000']
# ['R$', '2.300.000']
# ['R$', '669.000']
# ['R$', '4.412.000']
# ['R$', '1.700.000']
# ['R$', '6.500.000']
# ['R$', '3.000.000']
# ['R$', '11.000', '/Mês']
# ['R$', '2.200.000']
# ['R$', '2.750.000']
# ['R$', '1.250.000']

# %% [markdown]
# Como estou tentando usar uma função que é usanda em str em uma Series inteira do Data Frame, eu preciso informar que essa função é para str.

# %%
data_base['Valor'].str.split()
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %% [markdown]
# Consigo criar uma coluna para cada um dos elementos que foram separados por espaço.

# %%
data_base['Valor'].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %% [markdown]
# Felizmente, na primeira coluna não existe nenhum número misturado com os $.

# %%
data_base['Valor'].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %% [markdown]
# Felizmente, também não existe nenhum número misturado com essa terceira coluna

# %%
data_base['Valor'].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
len(data_base['Valor'].str.split(expand = True)[1].unique())
# Out:
# 1038

# %% [markdown]
# Adicionando no Data Frame essas colunas obtidas com o split.

# %%
data_base[['Moeda', 'Valor_Imovel', 'Tipo_de_Contrato']] = data_base['Valor'].str.split(expand = True)
data_base
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %% [markdown]
# Vou querer apenas aquelas linhas do Data Frame cujo o Tipo_de_Contrato é igual a null.

# %%
data_base[data_base['Tipo_de_Contrato'].isnull()]
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_Imovel  \
# ...

# %%
data_base[data_base['Tipo_de_Contrato'].isnull()]['Tipo_de_Contrato'].unique()
# Out:
# array([None], dtype=object)

# %% [markdown]
# Ao invés de salvar no Data Frame original, é aconselhavel criar uma outra variável para armazenar os dados filtrados.

# %%
filtered_data = data_base[data_base['Tipo_de_Contrato'].isnull()]
filtered_data
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_Imovel  \
# ...

# %% [markdown]
# Transformando os dados de Valor_do_Imovel para o tipo float.

# %%
filtered_data['Valor_Imovel'].str.replace('.', '').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_Imovel, Length: 9156, dtype: float64

# %%
filtered_data['Valor_Imovel_float'] = filtered_data['Valor_Imovel'].str.replace('.', '').astype(float)
filtered_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# ...

# %%
filtered_data.sample(21)
# Out:
#                                               Rua                      Bairro  \
# 4615                                          NaN             Jardim Paulista
# 10                  Rua Vigário João Álvares, 66               Vila Monumento
# 149                             Rua Monte Cardoso              Vila Antonieta
# 9164                                          NaN               Cidade Vargas
# 3509                                Rua Araripina              Jardim Guedala
# 5111                  Rua Diogo Rodrigues Marques                Campo Grande
# 1554                              Rua dos Tamanás               Vila Madalena
# 1470                            Rua Domingos Leme         Vila Nova Conceição
# 778                                           NaN           Alto de Pinheiros
# 4608                                          NaN           Alto de Pinheiros
# 1579                      Rua Engenheiro Sá Rocha                    Vila Ida
# ...

# %% [markdown]
# Perceba que o tipo de Valor_Imovel_float realmente é float.

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rua                 6107 non-null   object
#  1   Bairro              9146 non-null   object
#  2   Cidade              9156 non-null   object
#  3   Metragem            9156 non-null   int64
#  4   Quartos             9156 non-null   int64
#  5   Banheiros           9156 non-null   int64
#  6   Vagas               9156 non-null   int64
#  7   Valor               9156 non-null   object
#  8   Moeda               9156 non-null   object
#  9   Valor_Imovel        9156 non-null   object
#  10  Tipo_de_Contrato    0 non-null      object
#  11  Valor_Imovel_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
filtered_data['Valor_Imovel_float'].plot.hist(bins = 50)

# %%
filtered_data.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_Imovel_float
# count        9.156000e+03
# mean         3.052203e+06
# std          3.944208e+06
# min          1.300000e+04
# 25%          8.900000e+05
# 50%          1.800000e+06
# 75%          3.500000e+06
# max          6.500000e+07

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
filtered_data.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_Imovel_float
# count   9156.00  9156.00    9156.00 9156.00             9156.00
# mean     434.42     3.45       3.80    3.96          3052202.96
# std     7856.42     1.05       1.97    2.60          3944208.19
# min       10.00     1.00       1.00    1.00            13000.00
# 25%      168.00     3.00       2.00    2.00           890000.00
# 50%      276.00     3.00       4.00    4.00          1800000.00
# 75%      450.00     4.00       5.00    5.00          3500000.00
# max   750000.00    16.00      40.00   50.00         65000000.00

# %%
filtered_data.describe(include = 'all')
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
filtered_data[['Rua', 'Bairro', 'Cidade']].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data = filtered_data, x = 'Valor_Imovel_float')

# %%
sns.set()
sns.histplot(data = filtered_data, x = 'Valor_Imovel_float')

# %%
sns.histplot(data = filtered_data, x = 'Valor_Imovel_float', kde = True)

# %%
plt.figure(figsize = (10, 10))
ax = sns.histplot(data = filtered_data, x = 'Valor_Imovel_float', kde = True)
ax.set_title('Histograma')
plt.xlim((-50, 10000021))
plt.show()

# %% [markdown]
# ## Desafios 🧐🤯😎:
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma, de valores, legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusões
# - Pesquisar uma visualização para analsisar os quartis, mediana e outliers

# %% [markdown]
# #### Desafio 1: Criar uma escala de valores em milhões.

# %%
filtered_data['Valor_Imovel_float'].apply(lambda x: x/1000000)
# Out:
# 0       7.00
# 1       3.70
# 2       0.38
# 3       0.69
# 4       0.54
#         ...
# 10002   1.50
# 10003   0.67
# 10004   2.30
# 10005   1.05
# 10007   0.27
# Name: Valor_Imovel_float, Length: 9156, dtype: float64

# %% [markdown]
# Também é possível fazer com a função transform

# %%
filtered_data['Valor_Imovel_float'].transform(lambda x: x/1000000)
# Out:
# 0       7.00
# 1       3.70
# 2       0.38
# 3       0.69
# 4       0.54
#         ...
# 10002   1.50
# 10003   0.67
# 10004   2.30
# 10005   1.05
# 10007   0.27
# Name: Valor_Imovel_float, Length: 9156, dtype: float64

# %%
filtered_data['Valor_Imovel_float_milhao'] = filtered_data['Valor_Imovel_float'].apply(lambda x: x/1000000)

filtered_data[['Valor_Imovel', 'Valor_Imovel_float', 'Valor_Imovel_float_milhao']].sample(21)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Valor_Imovel  Valor_Imovel_float  Valor_Imovel_float_milhao
# 8955      530.000           530000.00                       0.53
# 7084      930.000           930000.00                       0.93
# 6936    4.200.000          4200000.00                       4.20
# 5322    1.100.000          1100000.00                       1.10
# 622     3.200.000          3200000.00                       3.20
# 3655    4.700.000          4700000.00                       4.70
# 2096    1.650.000          1650000.00                       1.65
# ...

# %% [markdown]
# #### Desafio 2: Deixar o gráfico do histograma, de valores, legível (alterar labels, cores, título, escala).

# %%
plt.figure(figsize = (10, 5))
values_histogram = sns.histplot(data = filtered_data, x = 'Valor_Imovel_float_milhao', color = 'Orange', binwidth = 21, element = 'poly')
values_histogram.set(title = 'Relação Entre a Quantidade de Imóveis e o seu Valor em Milhões de Reais')
sns.set_style('whitegrid')
values_histogram.set_xlabel('Valor (R$)')
values_histogram.set_ylabel('Quantidade')
plt.show()

# %% [markdown]
# #### Desafio 3: Preço do metro quadrado por bairro e plotar em um gráfico ideal.

# %%
mean_by_district = filtered_data[['Bairro', 'Valor_Imovel_float', 'Metragem']].groupby(['Bairro']).mean()
mean_by_district['Media_Preco_Metro_Por_Bairro'] = mean_by_district['Valor_Imovel_float'].div(mean_by_district['Metragem'])
mean_by_district = mean_by_district.sort_values(by = ['Media_Preco_Metro_Por_Bairro'], ascending = False)
mean_by_district
# Out:
#                               Valor_Imovel_float  Metragem  \
# Bairro
# Vila Guaca                             800000.00     10.00
# Jardim América                       16427596.64    646.31
# Jardim Teresa                        14836666.67    648.33
# Jardim Europa                        11496061.43    566.18
# Vila Nova Conceição                   5260913.98    299.32
# ...                                          ...       ...
# Jardim Brasília (Zona Leste)           320000.00    303.33
# Jardim Itapemirim                      215118.00    204.00
# Vila Aurea                             165000.00    182.00
# Jardim Vera Cruz(Zona Leste)           350000.00    642.50
# Sítio Represa                         2900000.00  37000.00
#
#                               Media_Preco_Metro_Por_Bairro
# Bairro
# Vila Guaca                                        80000.00
# Jardim América                                    25417.48
# Jardim Teresa                                     22884.32
# ...

# %%
plt.figure(figsize = (21, 10))
mean_by_district_lineplot = sns.lineplot(data = mean_by_district['Media_Preco_Metro_Por_Bairro'].head(10), linewidth = 1.5)
mean_by_district_lineplot.set(title = 'Média de Preço do Metro Quadrado por Bairro')
mean_by_district_lineplot.set_ylabel('Preço (R$)')
plt.show()

# %% [markdown]
# Outra maneira de obter a média de preço do metro:

# %%
filtered_data['V/M'] = filtered_data['Valor_Imovel_float'] / filtered_data['Metragem']
filtered_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# ...

# %%
by_district = filtered_data[['Bairro', 'V/M']].groupby(['Bairro']).mean().sort_values(by = ['V/M'], ascending = False)
by_district
# Out:
#                                   V/M
# Bairro
# Vila Guaca                   80000.00
# Jardim América               24088.57
# Jardim Ampliação             20051.04
# Jardim Europa                19962.69
# Vila Nova Conceição          17614.03
# ...                               ...
# Jardim Brasília (Zona Leste)  1055.01
# Jardim Itapemirim             1054.50
# Vila Aurea                     906.59
# Jardim Vera Cruz(Zona Leste)   544.76
# Sítio Represa                   78.38
#
# [697 rows x 1 columns]

# %% [markdown]
# #### Desafio 4: Explorar as bibliotecas de visualizações e colocar as suas conclusões.

# %% [markdown]
# Existem vários tipos de gráficos e, embora seja possível usar um tipo para vários casos diferentes, vale a pena ver qual tipo de gráfico consegue apresentar melhor a informação do caso.

# %% [markdown]
# #### Desafio 5: Pesquisar uma visualização para analsisar os quartis, mediana e outliers.

# %%
filtered_data.describe(include = 'all')
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
two_districts = filtered_data[(filtered_data['Bairro'] == 'Vila Mariana') | (filtered_data['Bairro'] == 'Alto de Pinheiros')]
two_districts

# %%
boxplot = sns.boxplot(data = two_districts, x = 'Bairro', y = 'Valor_Imovel_float_milhao')
boxplot.set_title('Variação do Valor em Alto de Pinheiros e Vila Mariana')
plt.show()
